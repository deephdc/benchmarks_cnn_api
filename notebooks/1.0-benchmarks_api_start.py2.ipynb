# %% [markdown]
# # benchmarks_api

# %% [markdown]
# Description: tf_cnn_benchmarks packed with DEEPaaS API

# %%
import socket
print(socket.gethostname())

# %%
import sys
sys.path.append('../benchmarks_api')

import matplotlib.pyplot as plt
# %matplotlib inline
